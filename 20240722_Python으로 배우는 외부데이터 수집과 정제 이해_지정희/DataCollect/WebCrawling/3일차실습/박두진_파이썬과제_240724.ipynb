# %% [markdown]
# ## 과제 사용법 실습하기
# - 네이버 지식인에서 키워드 검색 (예. 빅데이터) 결과 파싱하기
#     - https://kin.naver.com
#     - https://kin.naver.com/search/list.naver?query=%EC%98%A4%ED%94%88ai&page=2
#     - 제목,링크,날짜,카테고리,답변수
#         - 주의) 클래스 이름에 특수문자가 있는 경우 \\처리 해야 함.
#         - 사용자가 정한 페이지 수 만큼 가져오기

# %%
import requests
import pandas as pd

from urllib.parse import quote

import bs4 as sdsd

def kin_naver_parse():#(query = '', page = 1):    
    query = str(input('조회 할 검색어를 입력해주세요 =>'))
    page = str(input('조회 할 페이지 수를 입력해주세요 =>'))
    
    lst = []
    i = 0
    query = quote(query, safe='')       # 한글 인코딩
    
    while(True):
        i += 1
        
        url = f'https://kin.naver.com/search/list.naver?query={query}&page={i}'
        header = {
            'User-Agent' : 'Mozilla/5.0',
            'Referer' : url
        }

        print(url)
        
        response = requests.get(url, headers=header)
        result = response.text

        from bs4 import BeautifulSoup

        soup = BeautifulSoup(result, 'html.parser')
        #print(soup.prettify())

        items = soup.select("ul.basic1 > li")
        # print(type(items))
        # print(len(items),'\r\n', items)
    
        for news in items:
            # 제목,링크,날짜,카테고리,답변수
            제목 = news.select_one('dl > dt > a').text.strip()
            링크 = news.select_one('dl > dt > a').attrs['href'].strip()
            날짜 = news.select_one('dl > dd.txt_inline').text.strip()
            카테고리 = news.select_one('dl > dd.txt_block > a.txt_g1._nclicks\\:kin\\.cat2').text.strip()
            답변수 = news.select_one('dl > dd.txt_block > span.hit').text.strip().replace('답변수', '')
          
            lst.append([제목, 링크, 날짜, 카테고리, 답변수])
        
        print(lst)
        if page == str(i): break

    df = pd.DataFrame(lst, columns = ['제목', '링크', '날짜', '카테고리', '답변수'])
    return df

# %%
df = kin_naver_parse()
df
# Out:
# https://kin.naver.com/search/list.naver?query=%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0&page=1
# [['빅데이터분석기사 시험', 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=111&docId=471023333&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=1&search_sort=0&spq=0', '2024.06.26.', '컴퓨터 자격증, 학원', ' 7'], ['ios 개발자가 빅데이터를 다룰 수 있을 때', 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=1040105&docId=470821883&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=2&search_sort=0&spq=0', '2024.06.10.', 'iOS', ' 2'], ['빅데이터 분석기사 응시 자격', 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=1107&docId=465598733&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=3&search_sort=0&spq=0', '2024.06.16.', '평생교육', ' 6'], ['컴공vs빅데이터 공학과 전과 커리 비교...', 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=406&docId=471216561&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=4&search_sort=0&spq=0', '2024.06.21.', '직업, 취업', ' 2'], ['빅데이터 학과 노트북', 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10102&docId=472142291&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=5&search_sort=0&spq=0', '2024.07.10.', '노트북', ' 4'], ['오산대 빅데이터경영공학과', 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110408&docId=472519167&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=6&search_sort=0&spq=0', '2024.07.16.', '대학 입시, 진학', ' 3'], ['빅데이터 개발 전망', 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=471582174&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=7&search_sort=0&spq=0', '2024.06.25.', '컴퓨터, 프로그래밍', ' 2'], ['빅데이터전문가 자격증 따도 괜찮을까요?', 'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8030205&docId=471354287&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=8&search_sort=0&spq=0', '2024.06.20.', '헤어스타일링', ' 2'], ['컴공vs 빅데이터공학 전과', 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=471215929&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=9&search_sort=0&spq=0', '2024.06.18.', '컴퓨터, 프로그래밍', ' 4'], ['빅데이터분석기사 응시자격', 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110501&docId=362385656&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=10&search_sort=0&spq=0', '2024.07.08.', '대학공부', ' 2']]
# https://kin.naver.com/search/list.naver?query=%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0&page=2
# [['빅데이터분석기사 시험', 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=111&docId=471023333&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=1&search_sort=0&spq=0', '2024.06.26.', '컴퓨터 자격증, 학원', ' 7'], ['ios 개발자가 빅데이터를 다룰 수 있을 때', 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=1040105&docId=470821883&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=2&search_sort=0&spq=0', '2024.06.10.', 'iOS', ' 2'], ['빅데이터 분석기사 응시 자격', 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=1107&docId=465598733&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=3&search_sort=0&spq=0', '2024.06.16.', '평생교육', ' 6'], ['컴공vs빅데이터 공학과 전과 커리 비교...', 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=406&docId=471216561&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=4&search_sort=0&spq=0', '2024.06.21.', '직업, 취업', ' 2'], ['빅데이터 학과 노트북', 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10102&docId=472142291&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=5&search_sort=0&spq=0', '2024.07.10.', '노트북', ' 4'], ['오산대 빅데이터경영공학과', 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110408&docId=472519167&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=6&search_sort=0&spq=0', '2024.07.16.', '대학 입시, 진학', ' 3'], ['빅데이터 개발 전망', 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=471582174&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=7&search_sort=0&spq=0', '2024.06.25.', '컴퓨터, 프로그래밍', ' 2'], ['빅데이터전문가 자격증 따도 괜찮을까요?', 'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8030205&docId=471354287&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=8&search_sort=0&spq=0', '2024.06.20.', '헤어스타일링', ' 2'], ['컴공vs 빅데이터공학 전과', 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=471215929&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=9&search_sort=0&spq=0', '2024.06.18.', '컴퓨터, 프로그래밍', ' 4'], ['빅데이터분석기사 응시자격', 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110501&docId=362385656&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=10&search_sort=0&spq=0', '2024.07.08.', '대학공부', ' 2'], ['빅데이터개발자학원 괜찮은곳 소개좀......', 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10406&docId=417047407&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=11&search_sort=0&spq=0', '2024.06.11.', '프로그래밍 자격증, 학원', ' 9'], ['빅데이터 분석가가 되고 싶은데 관련...', 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=11050403&docId=472225120&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=12&search_sort=0&spq=0', '2024.07.09.', '자연과학대학', ' 1'], ['빅데이터분석준전문가랑...', 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=470917211&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=13&search_sort=0&spq=0', '2024.06.16.', '컴퓨터, 프로그래밍', ' 8'], ['지문 빅데이터', 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110304&docId=470894258&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=14&search_sort=0&spq=0', '2024.06.21.', '과학', ' 1'], ['자격증질문(오라클,빅데이터분석기사)', 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=406&docId=468136660&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=15&search_sort=0&spq=0', '2024.07.08.', '직업, 취업', ' 3'], ['빅데이터 전문가 송길영 일생 생애가...', 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=470871505&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=16&search_sort=0&spq=0', '2024.06.21.', '프로그래밍', ' 1'], ['계명대학교 경영빅데이터학과', 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110408&docId=470403587&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=17&search_sort=0&spq=0', '2024.05.31.', '대학 입시, 진학', ' 3'], ['빅데이터 전문가가 되려면 대학원을...', 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110408&docId=472610275&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=18&search_sort=0&spq=0', '2024.07.23.', '대학 입시, 진학', ' 2'], ['빅데이터 it 직종 종류', 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=472339862&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=19&search_sort=0&spq=0', '2024.07.15.', '컴퓨터, 프로그래밍', ' 3'], ['AI빅데이터융합 희망 고3 선택과목', 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110408&docId=4 ...
# https://kin.naver.com/search/list.naver?query=%EB%B9%85%EB%8D%B0%EC%9D%B4%ED%84%B0&page=3
# [['빅데이터분석기사 시험', 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=111&docId=471023333&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=1&search_sort=0&spq=0', '2024.06.26.', '컴퓨터 자격증, 학원', ' 7'], ['ios 개발자가 빅데이터를 다룰 수 있을 때', 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=1040105&docId=470821883&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=2&search_sort=0&spq=0', '2024.06.10.', 'iOS', ' 2'], ['빅데이터 분석기사 응시 자격', 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=1107&docId=465598733&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=3&search_sort=0&spq=0', '2024.06.16.', '평생교육', ' 6'], ['컴공vs빅데이터 공학과 전과 커리 비교...', 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=406&docId=471216561&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=4&search_sort=0&spq=0', '2024.06.21.', '직업, 취업', ' 2'], ['빅데이터 학과 노트북', 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10102&docId=472142291&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=5&search_sort=0&spq=0', '2024.07.10.', '노트북', ' 4'], ['오산대 빅데이터경영공학과', 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110408&docId=472519167&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=6&search_sort=0&spq=0', '2024.07.16.', '대학 입시, 진학', ' 3'], ['빅데이터 개발 전망', 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=471582174&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=7&search_sort=0&spq=0', '2024.06.25.', '컴퓨터, 프로그래밍', ' 2'], ['빅데이터전문가 자격증 따도 괜찮을까요?', 'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=8030205&docId=471354287&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=8&search_sort=0&spq=0', '2024.06.20.', '헤어스타일링', ' 2'], ['컴공vs 빅데이터공학 전과', 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=471215929&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=9&search_sort=0&spq=0', '2024.06.18.', '컴퓨터, 프로그래밍', ' 4'], ['빅데이터분석기사 응시자격', 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110501&docId=362385656&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=10&search_sort=0&spq=0', '2024.07.08.', '대학공부', ' 2'], ['빅데이터개발자학원 괜찮은곳 소개좀......', 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=10406&docId=417047407&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=11&search_sort=0&spq=0', '2024.06.11.', '프로그래밍 자격증, 학원', ' 9'], ['빅데이터 분석가가 되고 싶은데 관련...', 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=11050403&docId=472225120&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=12&search_sort=0&spq=0', '2024.07.09.', '자연과학대학', ' 1'], ['빅데이터분석준전문가랑...', 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=470917211&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=13&search_sort=0&spq=0', '2024.06.16.', '컴퓨터, 프로그래밍', ' 8'], ['지문 빅데이터', 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110304&docId=470894258&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=14&search_sort=0&spq=0', '2024.06.21.', '과학', ' 1'], ['자격증질문(오라클,빅데이터분석기사)', 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=406&docId=468136660&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=15&search_sort=0&spq=0', '2024.07.08.', '직업, 취업', ' 3'], ['빅데이터 전문가 송길영 일생 생애가...', 'https://kin.naver.com/qna/detail.naver?d1id=1&dirId=104&docId=470871505&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=16&search_sort=0&spq=0', '2024.06.21.', '프로그래밍', ' 1'], ['계명대학교 경영빅데이터학과', 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110408&docId=470403587&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=17&search_sort=0&spq=0', '2024.05.31.', '대학 입시, 진학', ' 3'], ['빅데이터 전문가가 되려면 대학원을...', 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110408&docId=472610275&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=18&search_sort=0&spq=0', '2024.07.23.', '대학 입시, 진학', ' 2'], ['빅데이터 it 직종 종류', 'https://kin.naver.com/qna/detail.naver?d1id=4&dirId=40608&docId=472339862&qb=67mF642w7J207YSw&enc=utf8§ion=kin.qna_ency&rank=19&search_sort=0&spq=0', '2024.07.15.', '컴퓨터, 프로그래밍', ' 3'], ['AI빅데이터융합 희망 고3 선택과목', 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110408&docId=4 ...
#                           제목  \
# 0                빅데이터분석기사 시험
# 1   ios 개발자가 빅데이터를 다룰 수 있을 때
# 2            빅데이터 분석기사 응시 자격
# 3   컴공vs빅데이터 공학과 전과 커리 비교...
# 4                빅데이터 학과 노트북
# 5              오산대 빅데이터경영공학과
# 6                 빅데이터 개발 전망
# 7      빅데이터전문가 자격증 따도 괜찮을까요?
# 8             컴공vs 빅데이터공학 전과
# 9              빅데이터분석기사 응시자격
# 10  빅데이터개발자학원 괜찮은곳 소개좀......
# 11    빅데이터 분석가가 되고 싶은데 관련...
# 12            빅데이터분석준전문가랑...
# 13                   지문 빅데이터
# 14       자격증질문(오라클,빅데이터분석기사)
# 15    빅데이터 전문가 송길영 일생 생애가...
# 16            계명대학교 경영빅데이터학과
# 17     빅데이터 전문가가 되려면 대학원을...
# 18             빅데이터 it 직종 종류
# 19       AI빅데이터융합 희망 고3 선택과목
# 20                   빅데이터전문가
# 21         빅데이터 법률 뉴스좀 알려주세요
# 22                 빅데이터 활용사례
# 23    빅데이터 전문가 외 직업이 하는 일...
# 24          빅데이터분석기사 응시자격 관련
# 25            빅데이터분석기사 자격 요건
# 26                    컴공빅데이터
# 27      부산빅데이터혁신센터 운영과 이용...
# 28  빅데이터(빅데이터를 이용한 ai)보고서...
# 29         빅데이터분석기사 관심이 생겼어요
#
#                                                    링크           날짜  \
# 0   https://kin.naver.com/qna/detail.naver?d1id=1&...  2024.06.26.
# 1   https://kin.naver.com/qna/detail.naver?d1id=1&...  2024.06.10.
# 2   https://kin.naver.com/qna/detail.naver?d1id=11...  2024.06.16.
# 3   https://kin.naver.com/qna/detail.naver?d1id=4&...  2024.06.21.
# 4   https://kin.naver.com/qna/detail.naver?d1id=1&...  2024.07.10.
# 5   https://kin.naver.com/qna/detail.naver?d1id=11...  2024.07.16.
# 6   https://kin.naver.com/qna/detail.naver?d1id=4&...  2024.06.25.
# 7   https://kin.naver.com/qna/detail.naver?d1id=8&...  2024.06.20.
# 8   https://kin.naver.com/qna/detail.naver?d1id=4&...  2024.06.18.
# 9   https://kin.naver.com/qna/detail.naver?d1id=11...  2024.07.08.
# 10  https://kin.naver.com/qna/detail.naver?d1id=1&...  2024.06.11.
# 11  https://kin.naver.com/qna/detail.naver?d1id=11...  2024.07.09.
# 12  https://kin.naver.com/qna/detail.naver?d1id=4&...  2024.06.16.
# 13  https://kin.naver.com/qna/detail.naver?d1id=11...  2024.06.21.
# 14  https://kin.naver.com/qna/detail.naver?d1id=4&...  2024.07.08.
# 15  https://kin.naver.com/qna/detail.naver?d1id=1&...  2024.06.21.
# 16  https://kin.naver.com/qna/detail.naver?d1id=11...  2024.05.31.
# 17  https://kin.naver.com/qna/detail.naver?d1id=11...  2024.07.23.
# 18  https://kin.naver.com/qna/detail.naver?d1id=4&...  2024.07.15.
# 19  https://kin.naver.com/qna/detail.naver?d1id=11...  2024.06.12.
# 20  https://kin.naver.com/qna/detail.naver?d1id=11...  2024.07.24.
# 21  https://kin.naver.com/qna/detail.naver?d1id=4&...  2024.07.18.
# 22  https://kin.naver.com/qna/detail.naver?d1id=11...  2024.06.28.
# 23  https://kin.naver.com/qna/detail.naver?d1id=7&...  2024.06.21.
# 24  https://kin.naver.com/qna/detail.naver?d1id=1&...  2024.07.21.
# 25  https://kin.naver.com/qna/detail.naver?d1id=4&...  2024.07.08.
# 26  https://kin.naver.com/qna/detail.naver?d1id=11...  2024.06.12.
# 27  https://kin.naver.com/qna/detail.naver?d1id=6&...  2024.07.17.
# 28  https://kin.naver.com/qna/detail.naver?d1id=11...  2024.07.17.
# 29  https://kin.naver.com/qna/detail.naver?d1id=11...  2024.07.08.
#
#              카테고리  답변수
# 0     컴퓨터 자격증, 학원    7
# 1             iOS    2
# 2            평생교육    6
# 3          직업, 취업    2
# 4             노트북    4
# 5       대학 입시, 진학    3
# 6      컴퓨터, 프로그래밍    2
# 7          헤어스타일링    2
# 8      컴퓨터, 프로그래밍    4
# 9            대학공부    2
# 10  프로그래밍 자격증, 학원    9
# 11         자연과학대학    1
# 12     컴퓨터, 프로그래밍    8
# 13             과학    1
# 14         직업, 취업    3
# 15          프로그래밍    1
# 16      대학 입시, 진학    3
# 17      대학 입시, 진학    2
# 18     컴퓨터, 프로그래밍    3
# 19      대학 입시, 진학    1
# 20         자연과학대학    1
# 21      경제 정책, 제도    1
# 22           기술가정    1
# 23         의료보건제도    1
# 24  정보보안 전문가, 자격증    2
# 25     컴퓨터, 프로그래밍   10
# 26             실과    2
# 27          국민신문고    1
# 28           기술가정    1
# 29           직업교육   10

# %%
df.to_excel('kin_naver.xlsx', index=False)
