# %% [markdown]
# ## BeautifulSoup 라이브러리

# %% [markdown]
# - 웹 페이지에서 정보를 쉽게 스크래핑하는 라이브러리
#     - HTML 뿐만 아니라, XML 파일 파싱도 쉽게 수행하는 라이브러리
#     - 구문 분석 트리를 사용하여 HTML 및 XML 파일을 탐색하고 검색하는 기능 제공
#     - 공식문서
#         - https://www.crummy.com/software/BeautifulSoup/bs4/doc/#quick-start
# - 주요 특징
#     - HTML / XML 파싱
#     - 쉽고 직관적인 API
#     - 다양한 파서 지원 (html.parser, lxml, xml 등)
# - 설치
#     ```
#     pip install beautifulSoup4
#     pip install bs4
#     ```
#     - parser 설치
#     ```
#     pip install lxml
#     ```

# %%
import requests

url = 'https://www.naver.com'
response = requests.get(url)

if response.status_code == 200:
    # print(response.encoding)            # (UTF-8) 수신된 데이터의 인코딩 방법
    # print(response.apparent_encoding)   # (utf-8) 추정 인코딩 방법

    # print(type(response.content))       # <class 'bytes'>
    # print(response.content)
    # print(type(response.text))          # <class 'str'>
    # print(response.text)
    
    result = response.text
    print(result)
else:
    print('Failed : ', response.status_code)
# Out:
#    <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description"
# ...

# %% [markdown]
# ## BeautifulSoup 기본 사용법

# %%
#%pip install beautidulSoup4
# %pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from bs4 import BeautifulSoup

html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
soup = BeautifulSoup(html_doc, 'html.parser')
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %% [markdown]
# ### ◆ 특정 태그 추출

# %%
# 특정 태그 추출
print('soup.title : ', soup.title)
print('soup.title.name : ', soup.title.name)        # 태그이름
print('soup.title.string : ', soup.title.string)    # 태그내용
print('soup.title.text : ', soup.title.text)        # 태그내용
print('soup.title.parent.name : ', soup.title.parent.name)
# Out:
# soup.title :  <title>The Dormouse's story</title>
# soup.title.name :  title
# soup.title.string :  The Dormouse's story
# soup.title.text :  The Dormouse's story
# soup.title.parent.name :  head

# %% [markdown]
# ### ◆ 태그의 속성 접근

# %%
# 태그의 속성 접근
print('soup.p : ', soup.p)
print("soup.p['class'] : ", soup.p['class'])

print('soup.a : ', soup.a)
print('soup.a["class"] : ', soup.a['class'])    # a태그의 class 속성 값
print('soup.a["href"] : ', soup.a['href'])      # a태그의 href 속성 값
print('soup.a["id"] : ', soup.a['id'])          # a태그의 id 속성 값
# Out:
# soup.p :  <p class="title"><b>The Dormouse's story</b></p>
# soup.p['class'] :  ['title']
# soup.a :  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# soup.a["class"] :  ['sister']
# soup.a["href"] :  http://example.com/elsie
# soup.a["id"] :  link1

# %% [markdown]
# ### ◆ find() 메서드 이용하기
# - 첫 번째로 발견된 태그를 반환

# %%
print('soup.find("a") : ', soup.find("a"))
print('soup.find("a", string="Lacie") : ', soup.find("a", string="Lacie"))
print('soup.find(id = "link3") : ', soup.find(id = "link3"))
# Out:
# soup.find("a") :  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# soup.find("a", string="Lacie") :  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>
# soup.find(id = "link3") :  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %% [markdown]
# ### ◆ find_all() 메서드 이용하기
# - 모든 태그를 리스트로 반환

# %%
print('soup.find_all("a"): ', soup.find_all("a"))
# Out:
# soup.find_all("a"):  [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %% [markdown]
# ### CSS 선택자를 사용하여 태그 선택

# %% [markdown]
# #### ◆ select_one() 메서드 이용하기
# - 처음으로 매치되는 태그 객체 하나만 반환

# %%
soup.select_one('p.title')
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %% [markdown]
# #### ◆ select() 메서드 이용하기
# - 매치되는 모든 태그를 리스트로 반환

# %%
soup.select("a.sister")
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
links = soup.select("a.sister")
for link in links:
    print(link["href"])
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %% [markdown]
# #### ◆ 검색된 태그의 attrs 사용하기

# %%
soup.select_one("a").attrs
# Out:
# {'href': 'http://example.com/elsie', 'class': ['sister'], 'id': 'link1'}

# %%
print(soup.select_one("a").attrs['href'])
print(soup.select_one("a").attrs['class'])
print(soup.select_one("a").attrs['id'])
# Out:
# http://example.com/elsie
# ['sister']
# link1

# %% [markdown]
# ---
# - 태그의 .string 과 .text 구분해서 사용하기
#     - 태그의 문자열을 추출할 때 사용
#     - .string : 태그가 단일 자식 텍스트 노드를 가질 때 사용
#         - **태그 안에 또 다른 태그가 포함된 경우 None 반환**
#     - .text : 태그와 그 모든 자식의 텍스트를 추출

# %%
print('soup.select_one("a").string : ', soup.select_one("a").string)
print('soup.select_one("a").text : ', soup.select_one("a").text)
# Out:
# soup.select_one("a").string :  Elsie
# soup.select_one("a").text :  Elsie

# %% [markdown]
# ## 실습 (다음 뉴스 파싱)
# - 다음 뉴스 사이트
#     - https://news.daum.net
#     - 엑셀 저장하기
#     ```
#     pip install pandas
#     pip install openpyxl
#     ```

# %%
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests

url = 'https://news.daum.net/'
response = requests.get(url)

if response.status_code == 200:
    result = response.text
    print(result)
else:
    print('Failed : ', response.status_code)
# Out:
# <!DOCTYPE html>
#
#
#
# <html lang="ko" class="os_unknown none unknown version_0 ">
# <head>
# <meta charset="utf-8">
# <meta name="referrer" content="always" />
#
# <meta property="og:author" content="Daum 뉴스" />
# <meta property="og:site_name" content="다음뉴스" />
# <meta property="og:title" content="다음뉴스 | 홈"/>
# <meta property="og:image" content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" />
# <meta property="og:description" content="다음뉴스" />
# <meta property="og:url" content="https://news.daum.net/" />
# <link rel="shortcut icon" href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico">
#
# <title>다음뉴스 | 홈</title>
#
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
# <link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/56c4cce/style.css.merged.css" />
# <link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/56c4cce/calendar.css.merged.css" />
#
# <!--[if lte IE 8]>
# ...

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(result, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="os_unknown none unknown version_0" lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="always" name="referrer">
#    <meta content="Daum 뉴스" property="og:author"/>
#    <meta content="다음뉴스" property="og:site_name"/>
#    <meta content="다음뉴스 | 홈" property="og:title"/>
#    <meta content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" property="og:image"/>
#    <meta content="다음뉴스" property="og:description"/>
#    <meta content="https://news.daum.net/" property="og:url"/>
#    <link href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico" rel="shortcut icon"/>
#    <title>
#     다음뉴스 | 홈
#    </title>
#    <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#    <link href="//t1.daumcdn.net/media/kraken/news/56c4cce/style.css.merged.css" rel="stylesheet" type="text/css">
#     <link href="//t1.daumcdn.net/media/kraken/news/56c4cce/calendar.css.merged.css" rel="stylesheet" type="text/css"/>
#     <!--[if lte IE 8]>
# ...

# %%
items = soup.select(".list_newsissue > li")
print(type(items))
print(len(items),'\r\n', items)
# Out:
# <class 'bs4.element.ResultSet'>
# 20
#  [<li>
# <div class="item_issue" data-tiara-layer="headline1">
# <a class="wrap_thumb" data-tiara-custom="contentUniqueKey=hamny-20240724160301578&amp;clusterId=5889432,5969883,5939427,5590543,5913282,5150097,5969875&amp;clusterTitle=문화,[섹션2024] 뉴스홈-최신뉴스,[테스트] 언론사픽 3, 4번 포토 기사,[언론사픽] 주요뉴스,[종합순] 비복제기사(원천보도),섹션 실시간뉴스-문화,[섹션2024] 뉴스홈-주요뉴스&amp;keywordType=NONE,NONE,NONE,NONE,NONE,NONE,NONE" data-tiara-id="20240724160301578" data-tiara-layer="article_main" data-tiara-ordnum="1" data-tiara-type="harmony" href="https://v.daum.net/v/20240724160301578">
# <img &quot;그런="" &quot;방금="" alt="" class="thumb_g" src="https://img1.daumcdn.net/thumb/S192x120ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202407%2F24%2Fohmynews%2F20240724161201975xfnp.jpg&amp;scode=media2" 못="" 받는다&quot;"="" 사과="" 사과드렸다&quot;="" 세월호="" 유족="" 이진숙=""/>
# </a>
# <div class="cont_thumb">
# <span class="info_thumb">
# <span class="logo_cp">오마이뉴스</span>
# ...

# %%
# news = li[]
lst = []
for news in items:
    title = news.select_one('.tit_g > a').text.strip()                  # 뉴스타이틀
    link = news.select_one('.tit_g > a').attrs['href'].strip()          # 뉴스링크
    corp = news.select_one('.logo_cp').text.strip()                     # 언론사
    cate = news.select_one('.txt_category').text.strip()                # 카테고리
    
    lst.append([title, link, corp, cate])

# %%
print(lst)
# Out:
# [['이진숙 "방금 사과드렸다" 세월호 유족 "그런 사과 못 받는다"', 'https://v.daum.net/v/20240724160301578', '오마이뉴스', '문화'], ['간호법 논의 본격화…의협 "의사들 향한 보복"', 'https://v.daum.net/v/20240724142800292', '아시아경제', '사회'], ['‘효자 종목’ 양궁·‘유일한 구기’ 女 핸드볼, 첫 출격 [파리 올림픽]', 'https://v.daum.net/v/20240724160840808', '경기일보', '속보'], ["부천 법원 후문 도로 중앙분리대 '훼손'…시민 안전위협 [현장의 목소리]", 'https://v.daum.net/v/20240724160850814', '경기일보', '사회'], ["‘반쪽짜리 올특위’ 운영 중단…환자 55%, '5분미만' 진료", 'https://v.daum.net/v/20240724155600235', '경기일보', '사회'], ["[단독] 툭하면 '물폭탄'인데···'알바 직원' 쓰는 빗물펌프장", 'https://v.daum.net/v/20240724152259845', '서울경제', '사회'], ['‘하늘도 울었다’ 故 김민기, 동료들 배웅 속 영면', 'https://v.daum.net/v/20240724152808058', '쿠키뉴스', '속보'], ['한국 자살률 폭발 기점 2002년, 그해 사채시장 제도화가 있었다', 'https://v.daum.net/v/20240724160004413', '한국일보', '사회'], ['이진숙 "44년간 헌혈 안 했다? 이해할 수 없는 인신 모독"', 'https://v.daum.net/v/20240724152336871', '머니투데이', '정치'], ['"中 자본 먹튀" 동양·ABL생명 매각 \'잡음\'…"고객 보호 제대로"(종합)', 'https://v.daum.net/v/20240724145325397', '데일리안', '경제'], ["[단독] '정산 지연' 티몬 충전금 5
# ...

# %%
import pandas as pd
df = pd.DataFrame(lst, columns = ['뉴스타이틀', '뉴스링크', '언론사', '카테고리'])
df
# Out:
#                                                 뉴스타이틀  \
# 0                 이진숙 "방금 사과드렸다" 세월호 유족 "그런 사과 못 받는다"
# 1                           간호법 논의 본격화…의협 "의사들 향한 보복"
# 2            ‘효자 종목’ 양궁·‘유일한 구기’ 女 핸드볼, 첫 출격 [파리 올림픽]
# 3            부천 법원 후문 도로 중앙분리대 '훼손'…시민 안전위협 [현장의 목소리]
# 4                  ‘반쪽짜리 올특위’ 운영 중단…환자 55%, '5분미만' 진료
# 5                 [단독] 툭하면 '물폭탄'인데···'알바 직원' 쓰는 빗물펌프장
# 6                        ‘하늘도 울었다’ 故 김민기, 동료들 배웅 속 영면
# 7                한국 자살률 폭발 기점 2002년, 그해 사채시장 제도화가 있었다
# 8                  이진숙 "44년간 헌혈 안 했다? 이해할 수 없는 인신 모독"
# 9          "中 자본 먹튀" 동양·ABL생명 매각 '잡음'…"고객 보호 제대로"(종합)
# 10             [단독] '정산 지연' 티몬 충전금 5억여원 서울보증이 전액 보장한다
# 11  애 울음소리 두 달째 늘어 “결혼 증가 때문?”, 그 효과 얼마나.. ‘곡소리’ 더...
# 12                   눈 부릅뜬 '개미' 중국 직진‥한반도에 몰고올 '다음'은?
# 13           [단독] 변협, 수천만 원 '먹튀' 수임 판사 출신 변호사 '제명' 징계
# 14      [전문] 신평 "윤 대통령, '궁정쿠데타' 참지 않을 것…한동훈 대표 내칠 수도"
# 15         “결국 못 버티고 문 닫았다”…6월에만 1100곳 휴폐업, 한파 맞은 업종은
# ...

# %%
df.to_excel('daumnews.xlsx', index=False)

# %% [markdown]
# ## 실습 (멜론차트 파싱)
# - 멜론 사이트
#     - https://www.melon.com/chart/index.htm

# %%
import requests

url = 'https://www.melon.com/chart/index.htm'
header = {
    'User-Agent' : 'Mozilla/5.0',
    'Referer' : url
}

response = requests.get(url, headers=header)
result = response.text

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(result, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <title>
#    멜론차트&gt;TOP100&gt;멜론
#   </title>
#   <meta content="음악서비스, 멜론차트, 멜론TOP100, 최신음악, 인기가요, 뮤직비디오, 앨범, 플레이어, 스트리밍, 다운로드, 아티스트플러스, 아티스트채널" name="keywords"/>
#   <meta content="No.1 뮤직플랫폼 멜론! 최신 트렌드부터 나를 아는 똑똑한 음악추천까지!" name="description"/>
#   <meta content="ee85ff6db1fa8f2226bcb671ecb2bcdbcffb6f8b" name="naver-site-verification"/>
#   <meta content="q4tbTQhmxa4La3OdNLsNOCxrJ_WV6lUlBFrFW4-HqQc" name="google-site-verification"/>
#   <meta content="357952407588971" property="fb:app_id"/>
#   <meta content="Melon" property="og:title"/>
#   <meta content="https://cdnimg.melon.co.kr/resource/image/web/common/logo_melon142x99.png" property="og:image"/>
#   <meta content="음악이 필요한 순간, 멜론" property="og:description"/>
#   <meta content="http://www.melon.com/chart/index.htm" property="og:url"/>
# ...

# %%
#items = soup.select("#frm > div > table > tbody > tr")
items = soup.select("tbody > tr")
# print(type(items))
# print(len(items),'\r\n', items)

# %%
# news = li[]
lst = []
for news in items:
    rank = news.select_one('.rank').text.strip()                    # 순위
    title = news.select_one('span > a').text.strip()                # 노래제목
    singer = news.select_one('.ellipsis.rank02 > a').text.strip()   # 가수
    cnt = news.select_one('div > button > span.cnt').text.strip().replace('\t', '')   # 좋아요
    #cnt = news.select_one('span.cnt > .none').text.strip()   # 좋아요

    lst.append([rank, title, singer, cnt])

# %%
print(lst)
# Out:
# [['1', 'Supernova', 'aespa', '총건수\r\n0'], ['2', 'How Sweet', 'NewJeans', '총건수\r\n0'], ['3', 'Small girl (feat. 도경수(D.O.))', '이영지', '총건수\r\n0'], ['4', 'Supernatural', 'NewJeans', '총건수\r\n0'], ['5', 'Sticky', 'KISS OF LIFE', '총건수\r\n0'], ['6', '소나기', '이클립스 (ECLIPSE)', '총건수\r\n0'], ['7', '클락션 (Klaxon)', '(여자)아이들', '총건수\r\n0'], ['8', 'Bubble Gum', 'NewJeans', '총건수\r\n0'], ['9', '고민중독', 'QWER', '총건수\r\n0'], ['10', 'Armageddon', 'aespa', '총건수\r\n0'], ['11', '한 페이지가 될 수 있게', 'DAY6 (데이식스)', '총건수\r\n0'], ['12', '나는 아픈 건 딱 질색이니까', '(여자)아이들', '총건수\r\n0'], ['13', 'Magnetic', '아일릿(ILLIT)', '총건수\r\n0'], ['14', 'SPOT! (feat. JENNIE)', '지코 (ZICO)', '총건수\r\n0'], ['15', '해야 (HEYA)', 'IVE (아이브)', '총건수\r\n0'], ['16', '첫 만남은 계획대로 되지 않아', 'TWS (투어스)', '총건수\r\n0'], ['17', 'Welcome to the Show', 'DAY6 (데이식스)', '총건수\r\n0'], ['18', '예뻤어', 'DAY6 (데이식스)', '총건수\r\n0'], ['19', '천상연', '이창섭', '총건수\r\n0'], ['20', 'Boom Boom Bass', 'RIIZE', '총건수\r\n0'], ['21', '사랑은 늘 도망가', '임영웅', '총건수\r\n0'], ['22', '에피소드', '이무진', '총
# ...

# %%
df = pd.DataFrame(lst, columns = ['순위', '제목', '가수', '좋아요'])
df
# Out:
#      순위                            제목                  가수       좋아요
# 0     1                     Supernova               aespa  총건수\r\n0
# 1     2                     How Sweet            NewJeans  총건수\r\n0
# 2     3  Small girl (feat. 도경수(D.O.))                 이영지  총건수\r\n0
# 3     4                  Supernatural            NewJeans  총건수\r\n0
# 4     5                        Sticky        KISS OF LIFE  총건수\r\n0
# ..  ...                           ...                 ...       ...
# 95   96           Lucky Girl Syndrome          아일릿(ILLIT)  총건수\r\n0
# 96   97                          EASY  LE SSERAFIM (르세라핌)  총건수\r\n0
# 97   98                         Siren               RIIZE  총건수\r\n0
# 98   99                         내가 그댈                 하동균  총건수\r\n0
# 99  100                           Who                  지민  총건수\r\n0
#
# [100 rows x 4 columns]

# %%
df.to_excel('meoln.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.to_excel('meoln.xlsx', index=False)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 실습 (여러 페이지 데이터 추출하기)
# - 네이버 증권
#     - https://finance.naver.com/news/mainnews.naver?&page=1
#     - 뉴스제목, 링크, 기사내용요약, 언론사, 날짜

# %%
import requests

url = 'https://finance.naver.com/news/mainnews.naver'
header = {
    'User-Agent' : 'Mozilla/5.0',
    'Referer' : url
}

response = requests.get(url, headers=header)
result = response.text

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(result, 'html.parser')
print(soup.prettify())
# Out:
# <!--  global include -->
# <html lang="ko">
#  <head>
#   <title>
#    네이버페이 증권
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="text/javascript" http-equiv="Content-Script-Type"/>
#   <meta content="text/css" http-equiv="Content-Style-Type"/>
#   <meta content="네이버페이 증권" name="apple-mobile-web-app-title">
#    <meta content="http://finance.naver.com/news/mainnews.naver" property="og:url">
#     <meta content="주요뉴스 : 네이버페이 증권" property="og:title"/>
#     <meta content="관심종목의 실시간 주가를 가장 빠르게 확인하는 곳" property="og:description"/>
#     <meta content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png" property="og:image"/>
#     <meta content="article" property="og:type"/>
#     <meta content="" property="og:article:thumbnailUrl"/>
#     <meta content="네이버페이 증권" property="og:article:author"/>
#     <meta content="http://FINANCE.NAVER.COM" property="og:article:author:url"/>
# ...

# %%
#items = soup.select("#contentarea_left > div.mainNewsList._replaceNewsLink > ul > li")
items = soup.select("ul.newsList > li")
print(type(items))
print(len(items),'\r\n', items)
# Out:
# <class 'bs4.element.ResultSet'>
# 20
#  [<li class="block1">
# <dl>
# <dt class="thumb">
# <a href="/news/news_read.naver?article_id=0007684415&amp;office_id=421&amp;mode=mainnews&amp;type=&amp;date=2024-07-24&amp;page=1"><img onerror="this.src='https://ssl.pstatic.net/static/nfinance/2017/02/27/thumb_72x54.gif'" src="https://imgnews.pstatic.net/image/thumb70/421/2024/07/24/7684415.jpg"/></a>
# </dt>
# <dd class="articleSubject">
# <a href="/news/news_read.naver?article_id=0007684415&amp;office_id=421&amp;mode=mainnews&amp;type=&amp;date=2024-07-24&amp;page=1">"HBM 격차 못 좁혔나"…삼성전자 하락·SK하이닉스 상승 '희비'[핫종목]</a>
# </dd>
# <dd class="articleSummary">
# 										삼성전자가 엔비디아에 납품하기 위한 4세대 고대역폭메모리(HBM)인 HBM3 퀄테스트(품질 검증)을 통과했다는 소식에도 주가는 하락 마..
# 										<span class="press">뉴스1 </span>
# <span class="bar">|</span>
# <span class="wdate">2024-07-24 16:04:08</span>
# </dd>
# </dl>
# </li>, <li class="block1">
# <dl>
# <dt class="thumb">
# ...

# %%
# news = li[]
lst = []
for news in items:
    # 뉴스제목, 링크, 기사내용요약, 언론사, 날짜
    뉴스제목 = news.select_one('dl > dd.articleSubject > a').text.strip()
    링크 = news.select_one('dl > dd.articleSubject > a').attrs['href'].strip()
    기사내용요약 = news.select_one('dl > dd.articleSummary').text.strip()
    언론사 = news.select_one('dl > dd.articleSummary > span.press').text.strip()    
    날짜 = news.select_one('dl > dd.articleSummary > span.wdate').text.strip()    

    lst.append([뉴스제목, 링크, 기사내용요약, 언론사, 날짜])

# %%
print(lst)
# Out:
# [['"HBM 격차 못 좁혔나"…삼성전자 하락·SK하이닉스 상승 \'희비\'[핫종목]', '/news/news_read.naver?article_id=0007684415&office_id=421&mode=mainnews&type=&date=2024-07-24&page=1', '삼성전자가 엔비디아에 납품하기 위한 4세대 고대역폭메모리(HBM)인 HBM3 퀄테스트(품질 검증)을 통과했다는 소식에도 주가는 하락 마..\n\t\t\t\t\t\t\t\t\t\t뉴스1 \n|\n2024-07-24 16:04:08', '뉴스1', '2024-07-24 16:04:08'], ["코스피, 외인 '팔자'에 2750선 후퇴…2차전지株 동반 하락", '/news/news_read.naver?article_id=0005013753&office_id=015&mode=mainnews&type=&date=2024-07-24&page=1', "코스피지수가 하락했다. 개인과 기관이 순매수세로 지수 방어에 나섰지만 외국인의 '팔자'세가 강했다. 24일 코스피지수는 전날보다 15...\n\t\t\t\t\t\t\t\t\t\t한국경제 \n|\n2024-07-24 16:02:10", '한국경제', '2024-07-24 16:02:10'], ['부동산PF 발목 잡힌 중소형證…반등 돌파구 마련 ‘시급’', '/news/news_read.naver?article_id=0002854466&office_id=119&mode=mainnews&type=&date=2024-07-24&page=1', '국내 중소형 증권사들이 부동산 프로젝트파이낸싱(PF) 리스크로 실적 한파와 신용등급 조정 등 장기간 타격을 받고 있다. 올해 상반기 어..\n\t\t\t\t\t\t\t\t\t\t데일리안 \n|\n2024-07-24 15:58:08', '데일리안', '2024-07-24 15:58:08'], ["'테슬라 쇼크'에 국내 이차전지株 와르르…LG엔솔 역대 최저가", '/news/news_read.naver?article_i
# ...

# %%
df = pd.DataFrame(lst, columns = ['뉴스제목', '링크', '기사내용요약', '언론사', '날짜'])
df
# Out:
#                                           뉴스제목  \
# 0   "HBM 격차 못 좁혔나"…삼성전자 하락·SK하이닉스 상승 '희비'[핫종목]
# 1           코스피, 외인 '팔자'에 2750선 후퇴…2차전지株 동반 하락
# 2              부동산PF 발목 잡힌 중소형證…반등 돌파구 마련 ‘시급’
# 3           '테슬라 쇼크'에 국내 이차전지株 와르르…LG엔솔 역대 최저가
# 4                  외인·기관 돈뭉치 풀었다...MSCI 편입에 베팅
# 5                          한화에너지, 한화 공개매수 성공할까
# 6                금·주식·부동산…인플레이션을 이기는 투자법[마켓칼럼]
# 7           코인 예치금에 '4% 이자' 한밤중 철회 소동... 경쟁 과열
# 8         크리스피 크림, 주가 오를 때 됐나…월가 50% 상승 전망(영상)
# 9       '삼성 HBM3 통과설'에도 하이닉스 강세…배경은? [장 안의 화제]
# 10                      "축구 떨어졌어?"…김빠진 올림픽 수혜주
# 11  테슬라, 수익성 악화에 시간외서 8%↓…“로보택시 10.10 공개” (영상)
# 12           한양증권 매각 본격화…‘그들만의 리그’ 지적도[fn마켓워치]
# 13         우후죽순 전력설비 ETF, 뒷북 아니었네…깜짝실적에 주가 '쑥'
# 14                모래시계 된 증권산업...소형사 동반 구조조정 오나
# 15    "6개월새 31.32%↓" …  카카오게임즈, 추락 이유는?[STOCK]
# 16                   신성통상 공개매수 실패하자 ··· 급등한 주가
# 17          월 배당도 가능한 연 7%대 수익률 '리츠 투자'[실전재테크]
# 18  “상장 이후 최저가”...테슬라 충격에 대장주 LG엔솔도 ‘뚝’ [증시이슈]
# ...

# %%
df.to_excel('naver_finance.xlsx', index=False)

# %% [markdown]
# #### 실습 - page 여러개 가져오기

# %%
import requests

lst = []
first_title = ''
i = 0
#for i in range(1, 100):
while(True):
    i += 1    
    
    url = 'https://finance.naver.com/news/mainnews.naver?&page=' + str(i)
    header = {
        'User-Agent' : 'Mozilla/5.0',
        'Referer' : url
    }

    print(url)
    
    response = requests.get(url, headers=header)
    result = response.text

    from bs4 import BeautifulSoup

    soup = BeautifulSoup(result, 'html.parser')
    #print(soup.prettify())

    #items = soup.select("#contentarea_left > div.mainNewsList._replaceNewsLink > ul > li")
    items = soup.select("ul.newsList > li.block1")
    # print(type(items))
    # print(len(items),'\r\n', items)
   
    for news in items:
        
        # 뉴스제목, 링크, 기사내용요약, 언론사, 날짜
        뉴스제목 = news.select_one('dl > dd.articleSubject > a').text.strip()
        링크 = 'https://finance.naver.com' + news.select_one('dl > dd.articleSubject > a').attrs['href'].strip()
        기사내용요약 = news.select_one('dl > dd.articleSummary').text.strip()
        언론사 = news.select_one('dl > dd.articleSummary > span.press').text.strip()    
        날짜 = news.select_one('dl > dd.articleSummary > span.wdate').text.strip()    
                    
        lst.append([뉴스제목, 링크, 기사내용요약, 언론사, 날짜])

    # 마지막 페이지 체크
    if soup.select_one('.pgRR') == None: break
    
    #print(lst)
# Out:
# https://finance.naver.com/news/mainnews.naver?&page=1
# https://finance.naver.com/news/mainnews.naver?&page=2
# https://finance.naver.com/news/mainnews.naver?&page=3
# https://finance.naver.com/news/mainnews.naver?&page=4
# https://finance.naver.com/news/mainnews.naver?&page=5
# https://finance.naver.com/news/mainnews.naver?&page=6

# %%
df = pd.DataFrame(lst, columns = ['뉴스제목', '링크', '기사내용요약', '언론사', '날짜'])
df
# Out:
#                                              뉴스제목  \
# 0      "HBM 격차 못 좁혔나"…삼성전자 하락·SK하이닉스 상승 '희비'[핫종목]
# 1              코스피, 외인 '팔자'에 2750선 후퇴…2차전지株 동반 하락
# 2                 부동산PF 발목 잡힌 중소형證…반등 돌파구 마련 ‘시급’
# 3              '테슬라 쇼크'에 국내 이차전지株 와르르…LG엔솔 역대 최저가
# 4                     외인·기관 돈뭉치 풀었다...MSCI 편입에 베팅
# ..                                            ...
# 103  '날개없는 추락' 카카오페이 김범수 구속에 8% 급락… 신사업 제동[STOCK]
# 104                   오르긴 올랐는데 더 갈 수 있을까…혼돈의 반도체株
# 105          올해 140% 뛰었는데 증여까지…분주한 한미반도체 오너家[마켓인]
# 106                     ‘트럼프 수혜’ 우크라 재건株…알고 사야 이득
# 107                   美 불확실성에 갈팡질팡 外人…조선·방산株는 담았다
#
#                                                     링크  \
# 0    https://finance.naver.com/news/news_read.naver...
# 1    https://finance.naver.com/news/news_read.naver...
# 2    https://finance.naver.com/news/news_read.naver...
# 3    https://finance.naver.com/news/news_read.naver...
# 4    https://finance.naver.com/news/news_read.naver...
# ...

# %%
df.to_excel('naver_finance_2.xlsx', index=False)

# %% [markdown]
# ## 과제 사용법 실습하기
# - 네이버 지식인에서 키워드 검색 (예. 빅데이터) 결과 파싱하기
#     - https://kin.naver.com
#     - https://kin.naver.com/search/list.naver?query=%EC%98%A4%ED%94%88ai&page=2
#     - 제목,링크,날짜,카테고리,답변수
#         - 주의) 클래스 이름에 특수문자가 있는 경우 \\처리 해야 함.
#         - 사용자가 정한 페이지 수 만큼 가져오기

# %%
import requests
import pandas as pd
from urllib.parse import quote

def kin_naver_parse(query = '', page = 1):    
    # query = str(input('조회 할 검색어를 입력해주세요 =>'))
    # page = str(input('조회 할 페이지 수를 입력해주세요 =>'))
    
    lst = []
    i = 0
    
    while(True):
        i += 1
        
        #query = quote(query, safe='')       # 한글 인코딩
        url = f'https://kin.naver.com/search/list.naver?query={query}&page={i}'
        header = {
            'User-Agent' : 'Mozilla/5.0',
            'Referer' : url
        }

        print(url)
        
        response = requests.get(url, headers=header)
        result = response.text

        from bs4 import BeautifulSoup

        soup = BeautifulSoup(result, 'html.parser')
        #print(soup.prettify())

        items = soup.select("ul.basic1 > li")
        # print(type(items))
        # print(len(items),'\r\n', items)
    
        for news in items:
            # 제목,링크,날짜,카테고리,답변수
            제목 = news.select_one('dl > dt > a').text.strip()
            # 링크 = 'https://finance.naver.com' + news.select_one('dl > dd.articleSubject > a').attrs['href'].strip()
            # 날짜 = news.select_one('dl > dd.articleSummary').text.strip()
            # 카테고리 = news.select_one('dl > dd.articleSummary > span.press').text.strip()    
            # 답변수 = news.select_one('dl > dd.articleSummary > span.wdate').text.strip()    
          
            lst.append([제목])

        # 마지막 페이지 체크
        #if soup.select_one('a.next.\\_nclicks\\:kin\\.next') == None: break
        
        print(lst)
        if page == str(i): break

    df = pd.DataFrame(lst, columns = ['제목'])
    return df

# %%
kin_naver_parse('오픈ai', '5')
# Out:
# https://kin.naver.com/search/list.naver?query=오픈ai&page=1
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 kin_naver_parse('오픈ai', '5')
#
# Cell In[106], line 24, in kin_naver_parse(query, page)
#      17 header = {
#      18     'User-Agent' : 'Mozilla/5.0',
#      19     'Referer' : url
#      20 }
#      22 print(url)
# ---> 24 response = requests.get(url, headers=header)
#      25 result = response.text
#      27 from bs4 import BeautifulSoup
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ...

# %%
df.to_excel('naver_finance_2.xlsx', index=False)

# %% [markdown]
# ## 과제 사용법 실습하기
# - 논문 사이트 파싱하기
#     - https://www.riss.kr/search/Search.do
#     - 논문제목, 링크, 학술지명, 발행연도
#         - 주제어로 논문 검색 후, 파싱 (빅데이터)
#     - 주의

# %%
# 1 Page : iStartCount: 0
# 2 Page : iStartCount: 10
# 3 Page : iStartCount: 20
# ..
_params = {
    'arch': 'N',
    'searchGubun': True,
    'viewYn': 'OP',
    'query': '빅데이터',
    'iStartCount': 0,
    'iGroupView': 5,
    'icate': 'all',
    'colName': 're_a_kor',    
    'order': '/DESC',
    'onHanja': False,
    'strSort': 'RANK',
    'pageScale': 10,
    'fsearchMethod': 'search',
    'isFDetailSearch': 'N',
    'sflag': 1,
    'searchQuery': '빅데이터',
    'resultKeyword': '빅데이터',
    'pageNumber': 1}

# %%
import requests
import pandas as pd
#from urllib.parse import quote

def riss_parse():
    query = str(input('조회 할 검색어를 입력해주세요 =>'))
    page = str(input('조회 할 페이지 수를 입력해주세요 =>'))

    lst = []

    # =======================================
    # 조회 검색어 설정
    _params['query'] = query
    _params['searchQuery'] = query
    _params['resultKeyword'] = query
    # =======================================
    
    for i in range(1, int(page) + 1):
        url = 'https://www.riss.kr/search/Search.do'
        header = {
            'User-Agent' : 'Mozilla/5.0',
            'Referer' : url
        }

        # print(url)
        print('i : ', i, 'iStartCount : ', str((i - 1) * 10))
        
        # =======================================
        # 조회할 페이지수 관련 - iStartCount 설정
        # - 1Page : iStartCount = 0
        # - 2Page : iStartCount = 10
        # - 3Page : iStartCount = 20
        _params['iStartCount'] = str((i - 1) * 10)
        # =======================================
        
        response = requests.get(url, params = _params, headers=header)
        result = response.text

        from bs4 import BeautifulSoup

        soup = BeautifulSoup(result, 'html.parser')
        #print(soup.prettify())

        items = soup.select("div.srchResultListW > ul > li")
        # print(type(items))
        # print(len(items),'\r\n', items)

        for news in items:
            # 논문제목, 링크, 학술지명, 발행연도
            논문제목 = news.select_one('p.title > a').text.strip()
            링크 = 'https://www.riss.kr' + news.select_one('p.title > a').attrs['href'].strip()    
            학술지명 = news.select_one('p.etc > span:nth-child(4) > a').text.strip()    
            발행연도 = news.select_one('p.etc > span:nth-child(3)').text.strip()        
            
            lst.append([논문제목, 링크, 학술지명, 발행연도])

        # 마지막 페이지 체크
        #if soup.select_one('a.next.\\_nclicks\\:kin\\.next') == None: break

        print(len(lst), lst)

    df = pd.DataFrame(lst, columns = ['논문제목', '링크', '학술지명', '발행연도'])
    df

    df.to_excel('riss_parse.xlsx', index=False)

# %%
riss_parse()
# Out:
# i :  1 iStartCount :  0
# ...
